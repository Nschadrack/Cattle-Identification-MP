# %%
import os
import shutil
import random

from google.colab import drive

# %%
## Some constant variables
drive.mount('/content/drive')
CAPSTONE_PATH = "/content/drive/MyDrive/CMU/Fall 2023/Capstone Project - Team Cylab/CapStone/"  # replace it with your path to the drive for capstone shared with you
DATA_ROOT_PATH = os.path.join(CAPSTONE_PATH, 'data')
DATA_UNSEEN_PATH = os.path.join(DATA_ROOT_PATH, "UNSEEN_DATA")

# Comment and uncomment below two lines to toggle different datasets
data_dir = os.path.join(DATA_ROOT_PATH, 'LOW_QUALITY_WITH_OG')  # Final dataset with both Original dataser and low quality generated dataset
data_unseen_all = os.path.join(DATA_UNSEEN_PATH, "ALL")



# Define the paths for your dataset
train_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Train')
val_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Valid')
test_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Test')
feature_extractor_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Feature_Extractor')



# New Folders
# Training
train_25_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Train', '25')
train_50_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Train', '50')
train_100_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Train', '100')
train_180_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Train', '180')
train_210_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Train', '210')


# Validation
valid_25_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Valid', '25')
valid_50_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Valid', '50')
valid_100_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Valid', '100')
valid_180_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Valid', '180')
valid_210_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Valid', '210')


# Testing
test_25_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '25')
test_50_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '50')
test_100_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '100')
test_125_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '125')
test_150_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '150')
test_180_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '180')
test_200_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '200')
test_210_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '210')
test_220_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '220')
test_230_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '230')
test_250_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '250')
test_268_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Test', '268')


# Feature Extractor
feature_extractor_25_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '25')
feature_extractor_50_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '50')
feature_extractor_100_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '100')
feature_extractor_125_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '125')
feature_extractor_150_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '150')
feature_extractor_180_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '180')
feature_extractor_200_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '200')
feature_extractor_210_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '210')
feature_extractor_220_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '220')
feature_extractor_230_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '230')
feature_extractor_250_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '250')
feature_extractor_268_dir = os.path.join(DATA_ROOT_PATH, 'SPLIT_DATA_WITH_OG', 'Final_Experiment', 'Feature_Extractor', '268')
# Out:
# Mounted at /content/drive

# %%
def split_dataset(source_root, destination_dir, class_dirs):
    """
    The function which splits the dataset into train, validation and test
    """
    # Iterate through each class directory and split the data
    for class_dir in class_dirs:
        source_class_data_dir = os.path.join(source_root, class_dir)
        destin_class_data_dir = os.path.join(destination_dir, class_dir)


        os.makedirs(source_class_data_dir, exist_ok=True)
        os.makedirs(destin_class_data_dir, exist_ok=True)

        class_files = os.listdir(source_class_data_dir)


        for file in class_files:
            src = os.path.join(source_class_data_dir, file)
            dst = os.path.join(destin_class_data_dir, file)
            shutil.copy(src, dst)
            print(f"Copied: {src} to {dst}")

# %%
# List all subdirectories (each subdirectory corresponds to a class)
class_dirs = sorted([d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))])
train_valid_indices = [25, 50, 100, 180, 210]
test_feature_ex_indices = [25, 50, 100, 125, 150, 180, 200, 210, 220, 230, 250, 268]

# Train folders
train_directories = [train_25_dir, train_50_dir, train_100_dir, train_180_dir, train_210_dir]

# Valid directories
valid_directories = [valid_25_dir, valid_50_dir, valid_100_dir, valid_180_dir, valid_210_dir]


# Tesing directories
test_directories = [test_25_dir, test_50_dir, test_100_dir, test_125_dir, test_150_dir,
                    test_180_dir, test_200_dir, test_210_dir, test_220_dir, test_230_dir, test_250_dir, test_268_dir]

# Feature Extractor directories
feature_extractor_directories = [feature_extractor_25_dir, feature_extractor_50_dir, feature_extractor_100_dir,
                                 feature_extractor_125_dir, feature_extractor_150_dir, feature_extractor_180_dir,
                                 feature_extractor_200_dir, feature_extractor_210_dir, feature_extractor_220_dir,
                                 feature_extractor_230_dir, feature_extractor_250_dir, feature_extractor_268_dir]

# %%
# Splitting Training
for index, folder in enumerate(train_directories):
  target_classes = class_dirs[:train_valid_indices[index]]
  split_dataset(train_dir, folder, target_classes)

# %%
# Splitting Validation
for index, folder in enumerate(valid_directories):
  target_classes = class_dirs[:train_valid_indices[index]]
  split_dataset(val_dir, folder, target_classes)

# %%
# Splitting Testing
for index, folder in enumerate(test_directories):
  target_classes = class_dirs[:test_feature_ex_indices[index]]
  split_dataset(test_dir, folder, target_classes)
# Out:
# Streaming output truncated to the last 5000 lines.
# Copied: /content/drive/MyDrive/CMU/Fall 2023/Capstone Project - Team Cylab/CapStone/data/SPLIT_DATA_WITH_OG/Test/cattle_5633/cattle_5633_DSCF9044_flip.jpg to /content/drive/MyDrive/CMU/Fall 2023/Capstone Project - Team Cylab/CapStone/data/SPLIT_DATA_WITH_OG/Final_Experiment/Test/210/cattle_5633/cattle_5633_DSCF9044_flip.jpg
# Copied: /content/drive/MyDrive/CMU/Fall 2023/Capstone Project - Team Cylab/CapStone/data/SPLIT_DATA_WITH_OG/Test/cattle_5633/cattle_5633_DSCF9044_pers.jpg to /content/drive/MyDrive/CMU/Fall 2023/Capstone Project - Team Cylab/CapStone/data/SPLIT_DATA_WITH_OG/Final_Experiment/Test/210/cattle_5633/cattle_5633_DSCF9044_pers.jpg
# ...

# %%
# Splitting Feature Extractor
for index, folder in enumerate(feature_extractor_directories):
  target_classes = class_dirs[:test_feature_ex_indices[index]]
  split_dataset(feature_extractor_dir, folder, target_classes)

# %%
len(os.listdir(test_268_dir))
# Out:
# 268
