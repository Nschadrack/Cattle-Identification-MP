# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %% [markdown]
# ## Section 1: Exploring the dataset

# %%
""" Analyzing the number of images present per each cattle """

# Root path containing the dataset
root_path = 'C:/Users/Kevin Sebineza/Desktop/CMU Courses/2023 - Fall/Capstone/BeefCattle_Muzzle_Individualized/'
num_images = 0

# Iterate over each subdirectory
for dirpath, dirnames, filenames in os.walk(root_path):
    # Count the number of image files in the current subdirectory
    for filename in filenames:
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            num_images += 1

    # Print the number of image files in the current subdirectory
    print(f"Found {num_images} images for {dirpath.split('/')[-1]}")
    num_images = 0
# Out:
# Found 0 images for
# Found 8 images for cattle_0100
# Found 10 images for cattle_0200
# Found 17 images for cattle_0300
# Found 7 images for cattle_0400
# Found 14 images for cattle_0500
# Found 19 images for cattle_0600
# Found 16 images for cattle_0700
# Found 18 images for cattle_0800
# Found 12 images for cattle_0900
# Found 12 images for cattle_1000
# Found 11 images for cattle_1100
# Found 11 images for cattle_1200
# Found 12 images for cattle_1300
# Found 13 images for cattle_1400
# Found 6 images for cattle_1500
# Found 14 images for cattle_1600
# Found 12 images for cattle_1700
# Found 22 images for cattle_1800
# Found 8 images for cattle_1900
# Found 14 images for cattle_2000
# Found 4 images for cattle_2100
# Found 6 images for cattle_2200
# Found 6 images for cattle_2220
# Found 22 images for cattle_2300
# Found 14 images for cattle_2320
# Found 23 images for cattle_2400
# Found 33 images for cattle_2500
# Found 10 images for cattle_2510
# Found 27 images for cattle_2600
# Found 17 images for cattle_2700
# Found 15 images for cattle_2710
# Found 8 images for cattle_2740
# Found 24 images for cattle_2800
# Found 15 images for cattle_2900
# Found 6 images for cattle_2930
# Found 15 images for cattle_3000
# Found 13 images for cattle_3100
# Found 16 images for cattle_3200
# Found 13 images for cattle_3300
# Found 7 images for cattle_3400
# Found 4 images for cattle_3420
# Found 8 images for cattle_3802
# Found 12 images for cattle_3812
# Found 13 images for cattle_3814
# Found 19 images for cattle_3819
# Found 42 images for cattle_3832
# Found 14 images for cattle_3842
# Found 15 images for cattle_3844
# Found 21 images for cattle_3847
# Found 29 images for cattle_3852
# Found 16 images for cattle_3856
# Found 18 images for cattle_4208
# Found 6 images for cattle_4259
# Found 19 images for cattle_4323
# Found 10 images for cattle_4326
# Found 28 images for cattle_4330
# Found 20 images for cattle_4339
# Found 19 images for cattle_4347
# Found 21 images for cattle_4363
# Found 16 images for cattle_4369
# Found 24 images for cattle_4381
# Found 23 images for cattle_4385
# Found 7 images for cattle_4399
# Found 32 images for cattle_4421
# Found 22 images for cattle_4422
# Found 7 images for cattle_4451
# Found 26 images for cattle_4454
# Found 29 images for cattle_4456
# Found 25 images for cattle_4479
# Found 11 images for cattle_4488
# Found 29 images for cattle_4499
# Found 12 images for cattle_4537
# Found 18 images for cattle_4539
# Found 29 images for cattle_4545
# Found 4 images for cattle_4549
# Found 28 images for cattle_4551
# Found 23 images for cattle_4568
# Found 34 images for cattle_4607
# Found 70 images for cattle_4613
# Found 25 images for cattle_4614
# Found 34 images for cattle_4649
# Found 21 images for cattle_4668
# Found 19 images for cattle_4678
# Found 16 images for cattle_4679
# Found 19 images for cattle_4680
# Found 11 images for cattle_4685
# Found 31 images for cattle_4686
# Found 16 images for cattle_4716
# Found 5 images for cattle_4717
# Found 24 images for cattle_5809
# Found 14 images for cattle_5815
# Found 9 images for cattle_5816
# Found 22 images for cattle_5836
# Found 30 images for cattle_5844
# Found 25 images for cattle_5886
# Found 4 images for cattle_5925
# Found 38 images for cattle_5932
# Found 30 images for cattle_5953
# Found 45 images for cattle_5971
# Found 5 images for cattle_5986
# Found 32 images for cattle_6011
# Found 19 images for cattle_6012
# Found 12 images for cattle_6017
# Found 8 images for cattle_6022
# Found 22 images for cattle_6038
# Found 50 images for cattle_6066
# Found 26 images for cattle_6071
# Found 36 images for cattle_6084
# Found 20 images for cattle_6098
# Found 10 images for cattle_6124
# Found 18 images for cattle_6161
# Found 21 images for cattle_6167
# Found 12 images for cattle_6171
# Found 16 images for cattle_6184
# Found 12 images for cattle_6189
# Found 18 images for cattle_6191
# Found 17 images for cattle_6196
# Found 12 images for cattle_6197
# Found 14 images for cattle_6199
# Found 10 images for cattle_6210
# Found 12 images for cattle_6213
# Found 18 images for cattle_6216
# Found 12 images for cattle_6220
# Found 15 images for cattle_6226
# Found 6 images for cattle_6237
# Found 8 images for cattle_6253
# Found 10 images for cattle_6266
# Found 15 images for cattle_6276
# Found 12 images for cattle_6277
# Found 13 images for cattle_6278
# Found 12 images for cattle_6282
# Found 5 images for cattle_6283
# Found 14 images for cattle_6287
# Found 10 images for cattle_6294
# Found 10 images for cattle_6295
# Found 34 images for cattle_6313
# Found 32 images for cattle_6331
# Found 54 images for cattle_6333
# Found 13 images for cattle_6442
# Found 8 images for cattle_6446
# Found 10 images for cattle_6458
# Found 15 images for cattle_6479
# Found 9 images for cattle_6499
# Found 14 images for cattle_6505
# Found 18 images for cattle_6506
# Found 10 images for cattle_6530
# Found 12 images for cattle_6606
# Found 4 images for cattle_8050
# Found 10 images for cattle_8094
# Found 8 images for cattle_8095
# Found 10 images for cattle_9021
# Found 29 images for cattle_9029
# Found 31 images for cattle_9634
# Found 8 images for cattle_9635
# Found 18 images for cattle_9736
# Found 19 images for cattle_9742
# Found 10 images for cattle_9773
# Found 42 images for cattle_9798
# Found 10 images for cattle_9801

# %%
""" Visualizing sample images """

images = []
for subdirectory in os.listdir(root_path):
    # Construct the path to the subdirectory
    subdirectory_path = os.path.join(root_path, subdirectory)
    
    # Iterate over all files in the subdirectory and add images to the list
    for filename in os.listdir(subdirectory_path):
        img_path = os.path.join(subdirectory_path, filename)
        img = cv2.imread(img_path)
        if img is not None:
            images.append(img)

# Visualizing 5 sample images
for i in range(5):
    plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
    plt.show()

# %%
# orientation transformations
orientation_transform = torchvision.transforms.Compose([
    torchvision.transforms.RandomPerspective(distortion_scale=0.2),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.ToTensor()
])

# %%
# Applying transformations on the data
cattle_1   = torchvision.datasets.ImageFolder(data_dir, transform= orientation_transform)

# %%
# ''' Visualizing the images in our dataset '''
# # Function that displays cifar images
# def display_image(images, size):
#     n = len(images)
#     plt.figure()
#     plt.gca().set_axis_off()
#     im = np.vstack([np.hstack([images[np.random.choice(n)] for i in range(size)]) for i in range(size)])
#     plt.imshow(im) 
#     plt.show()

# # Displaying some pictures
# display_image(cattle_1, 5)
